# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import tensorflow as tf
from tensorflow import keras

# %%
df = pd.read_csv('data_2022.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#           Timestamp  PM2.5    PM10      NO    NO2     Nox    NH3    SO2    CO  \
# 0  01-01-2022 00:00  432.0  469.75  201.75  37.93  184.65  33.35  54.12  2.72
# 1  01-01-2022 01:00  366.5  402.25  120.88  45.18  122.58  33.70  39.83  2.02
# 2  01-01-2022 02:00  319.5  352.25   95.70  61.20  110.60  27.40  23.50  1.80
# 3  01-01-2022 03:00  281.5  319.75   95.70  62.15  111.05  25.15  19.75  1.68
# 4  01-01-2022 04:00  271.5  318.00   71.85  58.97   89.95  25.85  23.38  1.30
#
#    Ozone  Benzene (µg/m³)  Toluene (µg/m³)  Xylene (µg/m³)  O Xylene (µg/m³)  \
# 0  14.25              NaN              NaN             NaN               NaN
# 1  14.00              NaN              NaN             NaN               NaN
# 2  14.03              NaN              NaN             NaN               NaN
# 3  14.10              NaN              NaN             NaN               NaN
# 4  13.95              NaN              NaN             NaN               NaN
#
#    Eth-Benzene (µg/m³)  MP-Xylene (µg/m³)    AT     RH   WS      WD  RF  \
# 0                  NaN                NaN  5.25  81.90  0.3  150.50 NaN
# 1                  NaN                NaN  4.90  82.28  0.3  194.75 NaN
# 2                  NaN                NaN  5.05  82.18  0.3  206.00 NaN
# 3                  NaN                NaN  5.00  82.02  0.3  220.00 NaN
# 4                  NaN                NaN  4.58  82.02  0.3  197.50 NaN
#
#    TOT-RF (mm)    SR     BP  VWS (m/s)
# 0            0  5.42  976.5       0.08
# 1            0  5.30  976.5        NaN
# 2            0  5.30  976.5        NaN
# 3            0  5.40  976.5        NaN
# 4            0  5.35  976.5       0.00

# %%
df.columns
# Out:
# Index(['Timestamp', 'PM2.5', 'PM10', 'NO', 'NO2', 'Nox', 'NH3', 'SO2', 'CO',
#        'Ozone', 'Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)',
#        'O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)', 'AT',
#        'RH', 'WS', 'WD', 'RF', 'TOT-RF (mm)', 'SR', 'BP', 'VWS (m/s)'],
#       dtype='object')

# %%
df.drop(columns=['Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)','O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)','RF', 'TOT-RF (mm)','VWS (m/s)'], inplace=True)

# %%
df.head()
# Out:
#           Timestamp  PM2.5    PM10      NO    NO2     Nox    NH3    SO2    CO  \
# 0  01-01-2022 00:00  432.0  469.75  201.75  37.93  184.65  33.35  54.12  2.72
# 1  01-01-2022 01:00  366.5  402.25  120.88  45.18  122.58  33.70  39.83  2.02
# 2  01-01-2022 02:00  319.5  352.25   95.70  61.20  110.60  27.40  23.50  1.80
# 3  01-01-2022 03:00  281.5  319.75   95.70  62.15  111.05  25.15  19.75  1.68
# 4  01-01-2022 04:00  271.5  318.00   71.85  58.97   89.95  25.85  23.38  1.30
#
#    Ozone    AT     RH   WS      WD    SR     BP
# 0  14.25  5.25  81.90  0.3  150.50  5.42  976.5
# 1  14.00  4.90  82.28  0.3  194.75  5.30  976.5
# 2  14.03  5.05  82.18  0.3  206.00  5.30  976.5
# 3  14.10  5.00  82.02  0.3  220.00  5.40  976.5
# 4  13.95  4.58  82.02  0.3  197.50  5.35  976.5

# %%
df.isna().sum()
# Out:
# Timestamp      0
# PM2.5        213
# PM10         184
# NO           156
# NO2          130
# Nox          136
# NH3          205
# SO2          396
# CO           901
# Ozone        235
# AT            86
# RH            94
# WS            86
# WD            86
# SR            86
# BP            86
# dtype: int64

# %%
df = df.fillna(method='ffill')
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_13564\569672361.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill')

# %%
df.isna().sum()
# Out:
# Timestamp    0
# PM2.5        0
# PM10         0
# NO           0
# NO2          0
# Nox          0
# NH3          0
# SO2          0
# CO           0
# Ozone        0
# AT           0
# RH           0
# WS           0
# WD           0
# SR           0
# BP           0
# dtype: int64

# %%
df.index = pd.to_datetime(df['Timestamp'], format='%d-%m-%Y %H:%M')

# %%
df.head()
# Out:
#                             Timestamp  PM2.5    PM10      NO    NO2     Nox  \
# Timestamp
# 2022-01-01 00:00:00  01-01-2022 00:00  432.0  469.75  201.75  37.93  184.65
# 2022-01-01 01:00:00  01-01-2022 01:00  366.5  402.25  120.88  45.18  122.58
# 2022-01-01 02:00:00  01-01-2022 02:00  319.5  352.25   95.70  61.20  110.60
# 2022-01-01 03:00:00  01-01-2022 03:00  281.5  319.75   95.70  62.15  111.05
# 2022-01-01 04:00:00  01-01-2022 04:00  271.5  318.00   71.85  58.97   89.95
#
#                        NH3    SO2    CO  Ozone    AT     RH   WS      WD  \
# Timestamp
# 2022-01-01 00:00:00  33.35  54.12  2.72  14.25  5.25  81.90  0.3  150.50
# 2022-01-01 01:00:00  33.70  39.83  2.02  14.00  4.90  82.28  0.3  194.75
# 2022-01-01 02:00:00  27.40  23.50  1.80  14.03  5.05  82.18  0.3  206.00
# 2022-01-01 03:00:00  25.15  19.75  1.68  14.10  5.00  82.02  0.3  220.00
# 2022-01-01 04:00:00  25.85  23.38  1.30  13.95  4.58  82.02  0.3  197.50
#
#                        SR     BP
# Timestamp
# 2022-01-01 00:00:00  5.42  976.5
# 2022-01-01 01:00:00  5.30  976.5
# 2022-01-01 02:00:00  5.30  976.5
# 2022-01-01 03:00:00  5.40  976.5
# 2022-01-01 04:00:00  5.35  976.5

# %%
df.drop(columns=['Timestamp'], inplace=True)

# %%
pm2_mean = df['PM2.5'].mean()
pm2_std = df['PM2.5'].std()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
df_scaled = pd.DataFrame(df_scaled, columns=df.columns, index=df.index)
df_scaled.head()
# Out:
#                         PM2.5      PM10        NO       NO2       Nox  \
# Timestamp
# 2022-01-01 00:00:00  3.839297  2.301016  1.699831 -0.219458  1.448421
# 2022-01-01 01:00:00  3.070729  1.725967  0.802452  0.016187  0.706198
# 2022-01-01 02:00:00  2.519237  1.300005  0.523041  0.536882  0.562944
# 2022-01-01 03:00:00  2.073351  1.023129  0.523041  0.567759  0.568325
# 2022-01-01 04:00:00  1.956012  1.008220  0.258388  0.464400  0.316014
#
#                           NH3       SO2        CO     Ozone        AT  \
# Timestamp
# 2022-01-01 00:00:00  1.007771  5.889937  1.593152 -0.696211 -2.015509
# 2022-01-01 01:00:00  1.043993  3.994114  0.837360 -0.701493 -2.053758
# 2022-01-01 02:00:00  0.391991  1.827648  0.599826 -0.700860 -2.037366
# 2022-01-01 03:00:00  0.159133  1.330144  0.470261 -0.699380 -2.042830
# 2022-01-01 04:00:00  0.231577  1.811728  0.059974 -0.702550 -2.088728
#
#                            RH        WS        WD        SR        BP
# Timestamp
# 2022-01-01 00:00:00  0.756711 -0.760677 -1.217501 -0.697071 -1.936013
# 2022-01-01 01:00:00  0.775638 -0.760677  0.695952 -0.697997 -1.936013
# 2022-01-01 02:00:00  0.770657 -0.760677  1.182424 -0.697997 -1.936013
# 2022-01-01 03:00:00  0.762688 -0.760677  1.787810 -0.697225 -1.936013
# 2022-01-01 04:00:00  0.762688 -0.760677  0.814868 -0.697611 -1.936013

# %%
df_scaled['Seconds'] = df_scaled.index.map(pd.Timestamp.timestamp)
df_scaled.head()
# Out:
#                         PM2.5      PM10        NO       NO2       Nox  \
# Timestamp
# 2022-01-01 00:00:00  3.839297  2.301016  1.699831 -0.219458  1.448421
# 2022-01-01 01:00:00  3.070729  1.725967  0.802452  0.016187  0.706198
# 2022-01-01 02:00:00  2.519237  1.300005  0.523041  0.536882  0.562944
# 2022-01-01 03:00:00  2.073351  1.023129  0.523041  0.567759  0.568325
# 2022-01-01 04:00:00  1.956012  1.008220  0.258388  0.464400  0.316014
#
#                           NH3       SO2        CO     Ozone        AT  \
# Timestamp
# 2022-01-01 00:00:00  1.007771  5.889937  1.593152 -0.696211 -2.015509
# 2022-01-01 01:00:00  1.043993  3.994114  0.837360 -0.701493 -2.053758
# 2022-01-01 02:00:00  0.391991  1.827648  0.599826 -0.700860 -2.037366
# 2022-01-01 03:00:00  0.159133  1.330144  0.470261 -0.699380 -2.042830
# 2022-01-01 04:00:00  0.231577  1.811728  0.059974 -0.702550 -2.088728
#
#                            RH        WS        WD        SR        BP  \
# Timestamp
# 2022-01-01 00:00:00  0.756711 -0.760677 -1.217501 -0.697071 -1.936013
# 2022-01-01 01:00:00  0.775638 -0.760677  0.695952 -0.697997 -1.936013
# 2022-01-01 02:00:00  0.770657 -0.760677  1.182424 -0.697997 -1.936013
# 2022-01-01 03:00:00  0.762688 -0.760677  1.787810 -0.697225 -1.936013
# 2022-01-01 04:00:00  0.762688 -0.760677  0.814868 -0.697611 -1.936013
#
#                           Seconds
# Timestamp
# 2022-01-01 00:00:00  1.640995e+09
# 2022-01-01 01:00:00  1.640999e+09
# 2022-01-01 02:00:00  1.641002e+09
# 2022-01-01 03:00:00  1.641006e+09
# 2022-01-01 04:00:00  1.641010e+09

# %%
df = df_scaled.copy()

# %%
day = 60*60*24
year = 365.2425*day
month = 30.436875*day

df['Day sin'] = np.sin(df['Seconds'] * (2* np.pi / day))
df['Day cos'] = np.cos(df['Seconds'] * (2 * np.pi / day))
df['Year sin'] = np.sin(df['Seconds'] * (2 * np.pi / year))
df['Year cos'] = np.cos(df['Seconds'] * (2 * np.pi / year))
df['Month sin'] = np.sin(df['Seconds'] * (2 * np.pi / month))
df['Month cos'] = np.cos(df['Seconds'] * (2 * np.pi / month))

# %%
df.head()
# Out:
#                         PM2.5      PM10        NO       NO2       Nox  \
# Timestamp
# 2022-01-01 00:00:00  3.839297  2.301016  1.699831 -0.219458  1.448421
# 2022-01-01 01:00:00  3.070729  1.725967  0.802452  0.016187  0.706198
# 2022-01-01 02:00:00  2.519237  1.300005  0.523041  0.536882  0.562944
# 2022-01-01 03:00:00  2.073351  1.023129  0.523041  0.567759  0.568325
# 2022-01-01 04:00:00  1.956012  1.008220  0.258388  0.464400  0.316014
#
#                           NH3       SO2        CO     Ozone        AT  \
# Timestamp
# 2022-01-01 00:00:00  1.007771  5.889937  1.593152 -0.696211 -2.015509
# 2022-01-01 01:00:00  1.043993  3.994114  0.837360 -0.701493 -2.053758
# 2022-01-01 02:00:00  0.391991  1.827648  0.599826 -0.700860 -2.037366
# 2022-01-01 03:00:00  0.159133  1.330144  0.470261 -0.699380 -2.042830
# 2022-01-01 04:00:00  0.231577  1.811728  0.059974 -0.702550 -2.088728
#
#                            RH        WS        WD        SR        BP  \
# Timestamp
# 2022-01-01 00:00:00  0.756711 -0.760677 -1.217501 -0.697071 -1.936013
# 2022-01-01 01:00:00  0.775638 -0.760677  0.695952 -0.697997 -1.936013
# 2022-01-01 02:00:00  0.770657 -0.760677  1.182424 -0.697997 -1.936013
# 2022-01-01 03:00:00  0.762688 -0.760677  1.787810 -0.697225 -1.936013
# 2022-01-01 04:00:00  0.762688 -0.760677  0.814868 -0.697611 -1.936013
#
#                           Seconds       Day sin   Day cos  Year sin  Year cos  \
# Timestamp
# 2022-01-01 00:00:00  1.640995e+09 -8.652299e-12  1.000000  0.006709  0.999977
# 2022-01-01 01:00:00  1.640999e+09  2.588190e-01  0.965926  0.007426  0.999972
# 2022-01-01 02:00:00  1.641002e+09  5.000000e-01  0.866025  0.008143  0.999967
# 2022-01-01 03:00:00  1.641006e+09  7.071068e-01  0.707107  0.008859  0.999961
# 2022-01-01 04:00:00  1.641010e+09  8.660254e-01  0.500000  0.009576  0.999954
#
#                      Month sin  Month cos
# Timestamp
# 2022-01-01 00:00:00   0.080422   0.996761
# 2022-01-01 01:00:00   0.088992   0.996032
# 2022-01-01 02:00:00   0.097556   0.995230
# 2022-01-01 03:00:00   0.106113   0.994354
# 2022-01-01 04:00:00   0.114662   0.993405

# %%
df.drop(columns=['Seconds'], inplace=True)

# %%
df.head()
# Out:
#                         PM2.5      PM10        NO       NO2       Nox  \
# Timestamp
# 2022-01-01 00:00:00  3.839297  2.301016  1.699831 -0.219458  1.448421
# 2022-01-01 01:00:00  3.070729  1.725967  0.802452  0.016187  0.706198
# 2022-01-01 02:00:00  2.519237  1.300005  0.523041  0.536882  0.562944
# 2022-01-01 03:00:00  2.073351  1.023129  0.523041  0.567759  0.568325
# 2022-01-01 04:00:00  1.956012  1.008220  0.258388  0.464400  0.316014
#
#                           NH3       SO2        CO     Ozone        AT  \
# Timestamp
# 2022-01-01 00:00:00  1.007771  5.889937  1.593152 -0.696211 -2.015509
# 2022-01-01 01:00:00  1.043993  3.994114  0.837360 -0.701493 -2.053758
# 2022-01-01 02:00:00  0.391991  1.827648  0.599826 -0.700860 -2.037366
# 2022-01-01 03:00:00  0.159133  1.330144  0.470261 -0.699380 -2.042830
# 2022-01-01 04:00:00  0.231577  1.811728  0.059974 -0.702550 -2.088728
#
#                            RH        WS        WD        SR        BP  \
# Timestamp
# 2022-01-01 00:00:00  0.756711 -0.760677 -1.217501 -0.697071 -1.936013
# 2022-01-01 01:00:00  0.775638 -0.760677  0.695952 -0.697997 -1.936013
# 2022-01-01 02:00:00  0.770657 -0.760677  1.182424 -0.697997 -1.936013
# 2022-01-01 03:00:00  0.762688 -0.760677  1.787810 -0.697225 -1.936013
# 2022-01-01 04:00:00  0.762688 -0.760677  0.814868 -0.697611 -1.936013
#
#                           Day sin   Day cos  Year sin  Year cos  Month sin  \
# Timestamp
# 2022-01-01 00:00:00 -8.652299e-12  1.000000  0.006709  0.999977   0.080422
# 2022-01-01 01:00:00  2.588190e-01  0.965926  0.007426  0.999972   0.088992
# 2022-01-01 02:00:00  5.000000e-01  0.866025  0.008143  0.999967   0.097556
# 2022-01-01 03:00:00  7.071068e-01  0.707107  0.008859  0.999961   0.106113
# 2022-01-01 04:00:00  8.660254e-01  0.500000  0.009576  0.999954   0.114662
#
#                      Month cos
# Timestamp
# 2022-01-01 00:00:00   0.996761
# 2022-01-01 01:00:00   0.996032
# 2022-01-01 02:00:00   0.995230
# 2022-01-01 03:00:00   0.994354
# 2022-01-01 04:00:00   0.993405

# %%
def df_to_X_y(df, window_size=5):
    df_as_np = df.to_numpy()
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        row = list(df_as_np[i:i+window_size])
        X.append(row)
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
X, y = df_to_X_y(df, window_size=5)

# %%
X.shape, y.shape
# Out:
# ((8755, 5, 21), (8755,))

# %%
y
# Out:
# array([1.63626431, 1.54532688, 1.38691974, ..., 0.50688006, 0.86182939,
#        0.73275691])

# %%
X_train, y_train = X[:6000], y[:6000]
X_val, y_val = X[6000:7000], y[6000:7000]
X_test, y_test = X[7000:], y[7000:]
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((6000, 5, 21), (6000,), (1000, 5, 21), (1000,), (1755, 5, 21), (1755,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model4 = Sequential()
model4.add(InputLayer((5, 21)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                   │ (None, 64)             │        22,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,545 (88.07 KB)
#  Trainable params: 22,545 (88.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('model4/.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp4])
# Out:
# Epoch 1/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.6036 - root_mean_squared_error: 0.7738 - val_loss: 0.1930 - val_root_mean_squared_error: 0.4397
# Epoch 2/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1966 - root_mean_squared_error: 0.4432 - val_loss: 0.0841 - val_root_mean_squared_error: 0.2863
# Epoch 3/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1531 - root_mean_squared_error: 0.3909 - val_loss: 0.0747 - val_root_mean_squared_error: 0.2688
# Epoch 4/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1346 - root_mean_squared_error: 0.3660 - val_loss: 0.0707 - val_root_mean_squared_error: 0.2610
# Epoch 5/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1226 - root_mean_squared_error: 0.3492 - val_loss: 0.0688 - val_root_mean_squared_error: 0.2577
# Epoch 6/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0957 - root_mean_squared_error: 0.3090 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2539
# Epoch 7/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0936 - root_mean_squared_error: 0.3057 - val_loss: 0.0654 - val_root_mean_squared_error: 0.2509
# Epoch 8/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0824 - root_mean_squared_error: 0.2866 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2477
# Epoch 9/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0807 - root_mean_squared_error: 0.2834 - val_loss: 0.0629 - val_root_mean_squared_error: 0.2461
# Epoch 10/10
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0708 - root_mean_squared_error: 0.2657 - val_loss: 0.0618 - val_root_mean_squared_error: 0.2433

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
    predictions = model.predict(X).flatten()
    df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
    plt.plot(df['Predictions'][start:end])
    plt.plot(df['Actuals'][start:end])
    return df, mse(y, predictions)

# %%
plot_predictions1(model4, X_test, y_test, start=300, end=500)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# (      Predictions   Actuals
#  0        0.411234  1.246113
#  1        0.472984  0.841295
#  2        0.641377  0.298604
#  3        0.475845  0.110862
#  4        0.352359  0.093261
#  ...           ...       ...
#  1750     0.397894  0.313271
#  1751     0.393746  0.286870
#  1752     0.320174  0.506880
#  1753     0.443723  0.861829
#  1754     0.630431  0.732757
#
#  [1755 rows x 2 columns],
#  0.36293264108518725)

# %%
def postprocess_pm2(arr):
    arr = (arr*pm2_std) + pm2_mean
    return arr

# %%
def plot_predictions(model, X, y, start=0, end=100):
    predictions = model.predict(X)
    pm2_preds = postprocess_pm2(predictions[:, 0])
    pm2_actuals = postprocess_pm2(y)
    df = pd.DataFrame(data={'PM2.5 Predictions': pm2_preds,
                            'PM2.5 Actuals': pm2_actuals,
                            
                            })
    plt.plot(df['PM2.5 Predictions'][start:end])    
    plt.plot(df['PM2.5 Actuals'][start:end])
    return df[start:end]

# %%
post_processed_df = plot_predictions(model4, X_test, y_test)
post_processed_df
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#     PM2.5 Predictions  PM2.5 Actuals
# 0          139.850739     211.006062
# 1          145.113586     176.504093
# 2          159.465424     130.251453
# 3          145.357407     114.250539
# 4          134.832901     112.750454
# ..                ...            ...
# 95         223.797485     225.506890
# 96         199.516693     215.256305
# 97         180.386749     215.006290
# 98         159.143280     210.256019
# 99         153.967560     204.755705
#
# [100 rows x 2 columns]
